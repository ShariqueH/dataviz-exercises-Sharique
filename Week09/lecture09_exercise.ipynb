# %% [markdown]
# # Lecture 9 — Streamlit Foundations
# ## From Charts to Dashboards
#
# > **Dataset:** World Happiness Report 2023
#
# > **Big Book of Dashboards:** Introduction + Chapter 1 — What is a dashboard?

# %% [markdown]
# ---
# ## Opening: Model Answer Review

# %% [markdown]
# ---
# ## Design Principles - Part I: What Is a Dashboard?

# %% [markdown]
# ### 💡 The BBD definition:  A dashboard is a visual display of data used to monitor conditions and/or facilitate understanding.
#
# ### 💡 Two things matter in this definition:
#
# 1. It must be visual — numbers in a table are not a dashboard
# 2. It must have a purpose — monitoring OR understanding. If you cannot say which of these your dashboard does, you do not yet have a dashboard idea, you have a data collection
#
# ### 💡 Chart vs Dashboard — the key difference
#
# | | Chart | Dashboard |
# |---|---|---|
# | Answers | One question | Multiple related questions simultaneously |
# | Audience | Anyone | A specific person or role |
# | Usage | Once, to make a point | Repeatedly, to monitor over time |
# | Filters | None to minimal | User-controlled |
# | Success measure | Did the audience understand the message? | Does the audience return to use it? |
#
#
# ### 💡 The single-purpose rule
#
# Before any code, write this sentence:
#
# > ❌ *'This dashboard shows the World Happiness data.'* (topic, not purpose)
# > ✅ *'This dashboard helps a UN policy analyst see which countries lead on happiness and what factors drive the gap.'* (audience + purpose)

# %% [markdown]
# ---
# ## Design Principles - Part II: BBD Preattentive Attributes + Colour

# %% [markdown]
# ### 💡 Preattentive attributes
#
# - BBD (chapter 1) and SWD (chapter 4) say the same thing independently: our brains process certain visual properties in under 250 milliseconds, before conscious attention
# - Both books agree: colour, size, and length are the most powerful preattentive attributes. Use them deliberately on every dashboard element
#
# ### 💡 The 4 colour types
#
# | Type | When to use | Example |
# |---|---|---|
# | **Sequential** | One direction, ordered data | Sales by state: light→dark blue = low→high |
# | **Diverging** | Two directions from a midpoint | Profit: blue (positive) ↔ red (negative), white = zero |
# | **Categorical** | Unordered groups | Continent colours on a scatter plot |
# | **Highlight** | One thing that needs to stand out | The one bar or line you want the audience to look at first |

# %% [markdown]
# ---
# ## Let's Code Some Examples 💻
#
# > **HOW TO RUN:** Copy each block into `app.py`, run `streamlit run app.py`.

# %%
import streamlit as st
import pandas as pd

# %%
df = pd.read_csv('/Users/shariqueh/Desktop/Data Visualization - UE/data/world_happiness_2023.csv')

df.head()
# Out:
#   Country name            Regional indicator  Ladder score  \
# 0      Finland                Western Europe         7.804
# 1      Denmark                Western Europe         7.586
# 2      Iceland                Western Europe         7.525
# 3       Israel  Middle East and North Africa         7.473
# 4  Netherlands                Western Europe         7.464
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     71.9
# 1                 10.933           0.954                     72.7
# 2                 10.878           0.983                     72.5
# 3                 10.527           0.916                     72.4
# 4                 11.015           0.939                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.949       0.142                      0.179
# 1                         0.931       0.168                      0.234
# 2                         0.961       0.260                      0.150
# 3                         0.903       0.149                      0.826
# 4                         0.879       0.240                      0.296

# %%
print(dir(st))
# Out:
# ['Page', '_ContextProxy', '_DeltaGenerator', '_DeltaGeneratorSingleton', '_DeprecatedUserInfoProxy', '_Dialog', '_EXPERIMENTAL_QUERY_PARAMS_DEPRECATE_MSG', '_QueryParamsProxy', '_STREAMLIT_VERSION_STRING', '_SessionStateProxy', '_StatusContainer', '_UserInfoProxy', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_bidi_component', '_bottom', '_cache', '_cache_data', '_cache_resource', '_column_config', '_config', '_connection', '_deprecate_func_name', '_dg_singleton', '_dialog_decorator', '_event', '_fragment', '_gather_metrics', '_get_query_params', '_logger', '_login', '_logout', '_main', '_os', '_secrets_singleton', '_set_query_params', '_update_logger', 'altair_chart', 'area_chart', 'audio', 'audio_input', 'auth_util', 'badge', 'balloons', 'bar_chart', 'bokeh_chart', 'button', 'cache', 'cache_data', 'cache_resource', 'camera_input', 'caption', 'chat_input', 'chat_message', 'checkbox', 'cli_util', 'code', 'color_picker', 'column_config', 'columns', 'commands', 'components', 'config', 'config_option', 'config_util', 'connection', 'connections', 'container', 'context', 'cursor', 'data_editor', 'dataframe', 'dataframe_util', 'date_input', 'delta_generator', 'delta_generator_singletons', 'deprecation_util', 'development', 'dialog', 'divider', 'download_button', 'echo', 'elements', 'empty', 'env_util', 'error', 'error_util', 'errors', 'exception', 'expander', 'experimental_get_query_params', 'experimental_set_query_params', 'experimental_user', 'feedback', 'file_uploader', 'file_util', 'form', 'form_submit_button', 'fragment', 'get_option', 'graphviz_chart', 'header', 'help', 'html', 'image', 'info', 'json', 'latex', 'line_chart', 'link_button', 'logger', 'login', 'logo', 'logout', 'map', 'markdown', 'metric', 'multiselect', 'navigation', 'number_input', 'page_link', 'pdf', 'pills', 'plotly_chart', 'popover', 'progress', 'proto', 'pydeck_chart', 'pyplot', 'query_params', 'radio', 'rerun', 'runtime', 'scatter_chart', 'secrets', 'segmented_control', 'select_slider', 'selectbox', 'session_state', 'set_option', 'set_page_config', 'sidebar', 'slider', 'snow', 'source_util', 'space', 'spinner', 'status', 'stop', 'streamlit', 'string_util', 'subheader', 'success', 'switch_page', 'table', 'tabs', 'text', 'text_area', 'text_input', 'time_input', 'time_util', 'title', 'toast', 'toggle', 'type_util', 'url_util', 'user', 'user_info', 'util', 'vega_lite_chart', 'version', 'video', 'warning', 'watcher', 'write', 'write_stream']

# %%
# ── STEP 1: Minimal working app ──────────────────────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('/Users/shariqueh/Desktop/Data Visualization - UE/data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")
st.write(f"Data loaded: {len(df)} countries")
# Out:
# 2026-06-19 09:50:25.958 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:50:25.988
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-06-19 09:50:25.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:50:25.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:50:25.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:50:25.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:50:25.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# ── STEP 2: Add a chart + apply appropriate colour rule ───────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('/Users/shariqueh/Desktop/Data Visualization - UE/data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

top15 = df.nlargest(15, 'Score').sort_values('Score')

# The bars are ordered, not categorical — sequential blue (light→dark) is appropriate
fig = px.bar(top15, x='Score', y='Country', orientation='h',
             color='Score',
             color_continuous_scale='Blues',  
             range_color=[5.0, 8.5],
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})
fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  font=dict(family='Arial', size=12),
                  xaxis=dict(range=[0, 8.5]),  
                  coloraxis_showscale=False,
                  margin=dict(l=55,r=20,t=10,b=10))
fig.update_traces(marker_line_width=0)
fig.show()
st.plotly_chart(fig, width='stretch')  # always use this
# Out:
# 2026-06-19 09:51:50.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:51:50.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# ── STEP 3: Sidebar filter + reactive chart ──────────────────────────────
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv('/Users/shariqueh/Desktop/Data Visualization - UE/data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

st.title("World Happiness Dashboard")

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N countries", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]
top = filtered.nlargest(top_n, 'Score').sort_values('Score')

fig = px.bar(top, x='Score', y='Country', orientation='h',
             color_discrete_sequence=['#2E75B6'],  
             labels={'Score': 'Happiness Score (0–10)', 'Country': ''})

fig.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                  xaxis=dict(range=[0,8.5], gridcolor='#EEEEEE'),
                  yaxis=dict(showgrid=False),
                  font=dict(family='Arial', size=12),
                  margin=dict(l=55,r=20,t=10,b=10))

fig.update_traces(marker_line_width=0)

st.plotly_chart(fig, width='stretch')
# Out:
# 2026-06-19 09:52:37.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:52:37.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# ── STEP 4: Full dashboard — KPIs + columns layout + BBD colour ──────────
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="World Happiness", page_icon="🌍", layout="wide")

df = pd.read_csv('/Users/shariqueh/Desktop/Data Visualization - UE/data/world_happiness_2023.csv')
df.columns = ['Country','Region','Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

with st.sidebar:
    st.header("Filters")
    regions = ['All'] + sorted(df['Region'].unique().tolist())
    selected_region = st.selectbox("Region", regions)
    top_n = st.slider("Show top N", 5, 25, 15)

filtered = df if selected_region == 'All' else df[df['Region'] == selected_region]

st.title("🌍 World Happiness Dashboard")
st.caption("Source: World Happiness Report 2023 | Kaggle")

# KPI row — BBD: big numbers at the top, readable in 5 seconds
col1, col2, col3 = st.columns(3)
col1.metric("Countries", len(filtered))
col2.metric("Avg Score", f"{filtered['Score'].mean():.2f}",
            f"{filtered['Score'].mean()-df['Score'].mean():+.2f} vs global")
col3.metric("Happiest", filtered.nlargest(1,'Score')['Country'].values[0])

st.divider()

# Two-column layout
col_left, col_right = st.columns(2)

with col_left:
    st.subheader("Rankings")
    top = filtered.nlargest(top_n, 'Score').sort_values('Score')
    
    fig1 = px.bar(top, x='Score', y='Country', orientation='h',
                  color_discrete_sequence=['#2E75B6'],
                  labels={'Score':'Score (0–10)','Country':''})
    
    fig1.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       xaxis=dict(range=[0,8.5]), font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    fig1.update_traces(marker_line_width=0)
    st.plotly_chart(fig1, width='stretch')

with col_right:
    st.subheader("Score vs GDP")
    fig2 = px.scatter(filtered, x='GDP', y='Score', hover_name='Country',
                      # BBD categorical colour: continent = unordered group
                      color_discrete_sequence=['#E63946'])
    fig2.update_layout(plot_bgcolor='white', paper_bgcolor='white',
                       font=dict(family='Arial',size=12),
                       margin=dict(l=10,r=10,t=5,b=10))
    st.plotly_chart(fig2, width='stretch')

st.divider()
st.caption("Built with Streamlit + Plotly")
# Out:
# 2026-06-19 09:56:26.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 09:56:26.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ---
# ## Class Exercise 💪 💻

# %%
# ── STEP 6: Add a third chart of your choice using a DIVERGING colour scale ───────────────────────────
# something where values go above and below a meaningful midpoint
# Label the midpoint in an annotation.


r
diverging_df = filtered.sort_values('Score', ascending=False)

# 3. Diverging scale
fig3 = px.bar(
    diverging_df,
    x='Country',
    y='Score',
    color='Score',
    color_continuous_scale='RdBu',          # The diverging color scale
    color_continuous_midpoint=global_avg,   # Anchors the color transition here
    labels={'Score': 'Happiness Score (0-10)', 'Country': ''}
)

# 4. Midpoint annotation line
fig3.add_hline(
    y=global_avg,
    line_dash="dot",
    line_width=2,
    line_color="#333333",
    annotation_text=f"Global Average: {global_avg:.2f}",
    annotation_position="top right",
    annotation_font=dict(size=12, color="#333333")
)

# Clean up
fig3.update_layout(
    plot_bgcolor='white', 
    paper_bgcolor='white',
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=True, gridcolor='#EEEEEE'),
    margin=dict(l=20, r=20, t=40, b=20)
)
fig3.update_traces(marker_line_width=0)


st.plotly_chart(fig3, use_container_width=True)
# Out:
# 2026-06-19 10:01:24.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.870 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-19 10:01:24.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 10:01:24.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# ── STEP 6: Deploy to Streamlit Community Cloud ───────────────────────────
# 1. Save as app.py in your GitHub repo
# 2. Create requirements.txt:
#       streamlit
#       plotly
#       pandas
# 3. share.streamlit.io → New app → point to repo/app.py
# 4. Done — public URL in ~2 minutes

# For data: either commit to repo, or load from raw GitHub URL:
# df = pd.read_csv('https://raw.githubusercontent.com/USER/REPO/main/data/file.csv')
